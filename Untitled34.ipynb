# %% [markdown]
# <a href="https://colab.research.google.com/github/kingtweak69/Merging/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="samuelcardillo/Qwen3-Coder-Next-Opus-4.6-Reasoning-Distilled",
    local_dir="/content/drive/MyDrive/samuel-original",
    ignore_patterns=["*.gguf", "*.bin"]
)
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# '/content/drive/MyDrive/samuel-original'

# %%
import os

directory_path = "/content/drive/MyDrive/samuel-original"

# List all files and directories in the specified path
contents = os.listdir(directory_path)

print(f"Contents of {directory_path}:")
for item in contents:
    print(item)
# Out:
# Contents of /content/drive/MyDrive/samuel-original:
# .cache
# model-00003-of-00004.safetensors
# chat_template.jinja
# generation_config.json
# model-00002-of-00004.safetensors
# model-00001-of-00004.safetensors
# .gitattributes
# config.json
# README.md
# model-00004-of-00004.safetensors
# model.safetensors.index.json
# tokenizer.json
# tokenizer_config.json
